# %% [markdown]
# # JitCoder Project Fix Checklist
#
# Use this notebook as a tick-mark checklist while fixing the project.
#
# **Status:** ☐ Not started  ☐ In progress  ☐ Done

# %% [markdown]
# ## Phase 1 — Security and Repo Cleanup
# - [X] Remove `.env`, `.env.*`, `db.sqlite3`, `node_modules`, `dist`, `staticfiles` from git
# - [X] Create `.env.example` files for backend and frontend
# - [X] Save `requirements.txt` in UTF-8
# - [X] Remove duplicate/unnecessary Python packages

# %% [markdown]
# ## Phase 2 — Backend Protection
# - [X] Add `is_sample` field in `TestCase`
# - [X] Hide private test cases from normal users
# - [X] Create public/private testcase serializers
# - [X] Restrict write access to Problems/Contests/TestCases to admin only
# - [X] Allow users to see only their own submissions

# %% [markdown]
# ## Phase 3 — Judge and Submission Flow
# - [X] Separate `run-code/` and `submit-code/`
# - [X] Move judge helpers into `judge/services.py`
# - [X] Compare outputs safely with stripped text
# - [X] Store submission after judge result
# - [X] Show sample testcase details only to users

# %% [markdown]
# ## Phase 4 — Leaderboard and Contest Logic
# - [X] Rebuild leaderboard using best submission per problem
# - [X] Stop latest wrong submission from reducing score incorrectly
# - [X] Add `ContestParticipation` model
# - [X] Persist joined contest state in DB
# - [X] Block joining ended contests

# %% [markdown]
# ## Phase 5 — WebSocket Fixes
# - [X] Standardize event format as `{ event, data }`
# - [X] Add handlers for leaderboard updates
# - [X] Add handlers for submission updates
# - [X] Add handlers for participant count updates
# - [X] Match frontend socket parsing with backend payload

# %% [markdown]
# ## Phase 6 — Frontend API Cleanup
# - [X] Create one shared `api.js` client
# - [X] Use `VITE_API_BASE_URL` everywhere
# - [X] Use `VITE_WS_BASE_URL` everywhere
# - [X] Remove hardcoded localhost URLs
# - [X] Fix duplicate `/api/api/...` path issues

# %% [markdown]
# ## Phase 7 — Model and Serializer Cleanup
# - [X] Fix user serializer validation imports
# - [X] Ensure custom user uses `PermissionsMixin`
# - [X] Remove invalid `username` usage if model uses `email`
# - [X] Convert problem tags string into frontend-friendly list
# - [X] Use environment-based password reset frontend URL

# %% [markdown]
# ## Phase 8 — Deployment and Environment
# - [X] Use env-based Redis URL
# - [X] Use same timezone across Django and Celery
# - [X] Improve `build.sh` with `collectstatic` and `check --deploy`
# - [X] Verify production database config
# - [X] Keep dev and production settings clean

# %% [markdown]
# ## Phase 9 — UI and UX Polish
# - [ ] Make all pages fully theme compatible
# - [ ] Add 404 page
# - [ ] Improve editor layout and output panels
# - [ ] Add submission history UI
# - [ ] Improve dashboard cards and tables for dark mode

# %% [markdown]
# ## Phase 10 — Final Verification
# - [ ] Test login/register flow
# - [ ] Test contest join flow
# - [ ] Test run code flow
# - [ ] Test submit code flow
# - [ ] Test leaderboard ranking
# - [ ] Test WebSocket updates
# - [ ] Test theme toggle on all important pages
# - [ ] Test local and production API URLs

# %% [markdown]
# ## Notes
# - [ ] Bug fixed:
# - [ ] Need retest:
# - [ ] Deploy after this phase:
